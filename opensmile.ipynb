# %%
import opensmile
import pandas as pd
import numpy as np
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.Functionals,
)
y = smile.process_file('/home/huan/Desktop/DSP_lab4/2022dsplab-detecting-baby-sounds/Baby_Data/wav_train/train_0002.wav')
data_m = pd.DataFrame(y)
print(np.size(y.to_numpy()[0]))
print(y.to_numpy()[0])
# Out:
# 988
# [ 1.18293392e-04  1.79128790e-07  1.18114265e-04  2.90000000e+01
#   1.70000000e+01  1.98919024e-05  2.19511207e-06 -1.74250035e-05
#   1.86465968e-05  5.68528280e-10  3.25579022e-05  1.71725202e+00
#   4.73801851e+00  4.76492403e-07  1.53752717e-06  2.08214042e-05
#   1.06103471e-06  1.92838779e-05  2.03449126e-05  4.09593058e+00
#   3.95066530e-01  3.70086408e+00  2.90000000e+01  0.00000000e+00
#   1.57482314e+00  7.81713948e-02  2.45909423e-01  6.23206258e-01
#   5.31016231e-01  1.07439029e+00  9.41332996e-01  2.46241546e+00
#   7.97097564e-01  9.17898178e-01  2.37647390e+00  1.20800614e-01
#   1.45857573e+00  1.57937634e+00 -1.31447191e+01 -2.40557613e+01
#   1.09110422e+01  3.00000000e+00  3.40000000e+01 -1.99918633e+01
#  -7.32055306e-02 -1.87473698e+01  1.87348568e+00  5.34744740e+00
#   2.42777085e+00  6.57035410e-01  3.29454350e+00 -2.14850159e+01
#  -2.03452511e+01 -1.87223053e+01  1.13976479e+00  1.62294579e+00
# ...
